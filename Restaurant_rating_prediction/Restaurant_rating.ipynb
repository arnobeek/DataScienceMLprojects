# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
restaurant_data = pd.read_csv("Dataset .csv")
restaurant_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
restaurant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
restaurant_data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
restaurant_data.duplicated().sum()
# Out:
# 0

# %%
restaurant_data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
restaurant_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Group by city and calculate average cost
restaurant_data.groupby('City')['Average Cost for two'].mean().sort_values(ascending=False).head(5).plot(kind='bar');
plt.xlabel('City')
plt.ylabel('Amount')
plt.title('Average cost for two people (Top 5)')
plt.show()

# %%
# Cuisines total number of votes
data = restaurant_data.groupby('Cuisines')['Votes'].sum().reset_index()

# %%
data
# Out:
#                                        Cuisines  Votes
# 0                                       Afghani     39
# 1                     Afghani, Mughlai, Chinese      2
# 2                         Afghani, North Indian      0
# 3     Afghani, North Indian, Pakistani, Arabian      3
# 4                                       African    373
# ...                                         ...    ...
# 1820                       Western, Asian, Cafe    259
# 1821                 Western, Fusion, Fast Food     32
# 1822                              World Cuisine     95
# 1823            World Cuisine, Mexican, Italian    115
# 1824            World Cuisine, Patisserie, Cafe   1034
#
# [1825 rows x 2 columns]

# %%
data[data["Votes"]==0]
# Out:
#                                                Cuisines  Votes
# 2                                 Afghani, North Indian      0
# 164                                     Awadhi, Mughlai      0
# 185                       Bakery, Chinese, North Indian      0
# 193                 Bakery, Desserts, Fast Food, Mithai      0
# 208                                Bakery, Healthy Food      0
# 213                                Bakery, North Indian      0
# 214                                       Bakery, Pizza      0
# 224                                    Bengali, Chinese      0
# 234                             Beverages, Healthy Food      0
# 323                            Burger, Pizza, Fast Food      0
# 457                          Cafe, Mexican, Continental      0
# 463                                 Cafe, North Eastern      0
# 489                                       Cafe, Tibetan      0
# 524                           Chinese, Fast Food, Pizza      0
# ...

# %%
sns.pairplot(restaurant_data[['Average Cost for two', 'Aggregate rating','Votes']]);

# %%
restaurant_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
restaurant_data['Has Online delivery'].value_counts().plot(kind='pie')
plt.ylabel('')
plt.legend()
plt.show()

# %%
restaurant_data[['Aggregate rating','Rating text']].sort_values(by='Aggregate rating', ascending=False).head(4000)
# Out:
#       Aggregate rating Rating text
# 1381               4.9   Excellent
# 589                4.9   Excellent
# 374                4.9   Excellent
# 9303               4.9   Excellent
# 9299               4.9   Excellent
# ...                ...         ...
# 1194               3.3     Average
# 2262               3.3     Average
# 4323               3.3     Average
# 7847               3.3     Average
# 3798               3.3     Average
#
# [4000 rows x 2 columns]

# %%
restaurant_data = restaurant_data[restaurant_data['Rating text'] != 'Not rated']

# %%
restaurant_data['Rating text'].value_counts().plot(kind='pie')
plt.title('Rating Averages')
plt.ylabel('')
plt.show()

# %%
restaurant_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
X = restaurant_data[['Average Cost for two','Has Table booking','Has Online delivery', 'Price range']]

# %%
y = restaurant_data[['Aggregate rating']]

# %%
X
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7403 rows x 4 columns]

# %%
X['Price range'].value_counts()
# Out:
# Price range
# 1    2744
# 2    2711
# 3    1373
# 4     575
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
X['Has Table booking'] = labelencoder.fit_transform(X['Has Table booking'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6780\1767685086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Has Table booking'] = labelencoder.fit_transform(X['Has Table booking'])

# %%
X
# Out:
#       Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                     1100                  1                  No            3
# 1                     1200                  1                  No            3
# 2                     4000                  1                  No            4
# 3                     1500                  0                  No            4
# 4                     1500                  1                  No            4
# ...                    ...                ...                 ...          ...
# 9546                    80                  0                  No            3
# 9547                   105                  0                  No            3
# 9548                   170                  0                  No            4
# 9549                   120                  0                  No            4
# 9550                    55                  0                  No            2
#
# [7403 rows x 4 columns]

# %%
X['Has Online delivery'] = labelencoder.fit_transform(X['Has Online delivery'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6780\2959977150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Has Online delivery'] = labelencoder.fit_transform(X['Has Online delivery'])

# %%
labelencoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
X
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 0                     1100                  1                    0
# 1                     1200                  1                    0
# 2                     4000                  1                    0
# 3                     1500                  0                    0
# 4                     1500                  1                    0
# ...                    ...                ...                  ...
# 9546                    80                  0                    0
# 9547                   105                  0                    0
# 9548                   170                  0                    0
# 9549                   120                  0                    0
# 9550                    55                  0                    0
#
#       Price range
# 0               3
# 1               3
# 2               4
# 3               4
# 4               4
# ...           ...
# 9546            3
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error,root_mean_squared_error
import numpy as np

# %%
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test, predictions)))
    print("Root mean squared error on model is {}".format(root_mean_squared_error(y_test, predictions)))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictionsfromlr = lr.predict(X_test)

# %%
modelresults(predictionsfromlr)
# Out:
# Mean absolute error on model is 0.40335583149332055
# Root mean squared error on model is 0.5072744025310191

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
svrmodel = SVR()

# %%
param_gridsvr = {"C":[0.1,0.5],"kernel":["linear","poly"],"degree":[2]}

# %%
gridsvr = GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(X_train,y_train)
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
predgridsvr = gridsvr.predict(X_test)

# %%
modelresults(predgridsvr)
# Out:
# Mean absolute error on model is 0.3982593608766474
# Root mean squared error on model is 0.5066226161656109

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {
    "max_depth":[10,30],
    "min_samples_leaf":[1,2],
    "min_samples_split":[2,5]
}

# %%
treemodel = DecisionTreeRegressor()

# %%
gridtree = GridSearchCV(estimator=treemodel,param_grid=param_grid)

# %%
gridtree.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %%
treepredictions = gridtree.predict(X_test)

# %%
modelresults(treepredictions)
# Out:
# Mean absolute error on model is 0.35794492994012067
# Root mean squared error on model is 0.45872658121717325

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfrmodel = RandomForestRegressor()

# %%
param_gridrfr = {
    "max_depth":[5,15],
    "n_estimators":[2,5,10],
}

# %%
gridrfr = GridSearchCV(rfrmodel, param_gridrfr)

# %%
gridrfr.fit(X_train,y_train)
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
rfpredictions = gridrfr.predict(X_test)

# %%
modelresults(rfpredictions)
# Out:
# Mean absolute error on model is 0.3567900344055759
# Root mean squared error on model is 0.4553003213771411

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 10}

# %%
gridtree.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors":[9,11,13,15,17,18,19]}
knn_grid_search = GridSearchCV(knn, knn_param_grid)

# %%
knn_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [9, 11, 13, 15, 17, 18, 19]})

# %%
knn_preds = knn_grid_search.predict(X_test)

# %%
modelresults(knn_preds)
# Out:
# Mean absolute error on model is 0.3645472278490509
# Root mean squared error on model is 0.4616743087531796

# %%
knn_grid_search.best_params_
# Out:
# {'n_neighbors': 18}

# %%
from sklearn.ensemble import AdaBoostRegressor
ada =AdaBoostRegressor()
ada_param_grid = {
    "n_estimators":[50,100,200],
    "learning_rate":[0.1,0.5,1]
    }
ada_grid_search = GridSearchCV(ada,ada_param_grid)

# %%
ada_grid_search.fit(X_train,y_train)
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
adapreds = ada_grid_search.predict(X_test)

# %%
modelresults(adapreds)
# Out:
# Mean absolute error on model is 0.3680419297213653
# Root mean squared error on model is 0.46604118277698425

# %%
import joblib
joblib.dump(gridrfr,"mlmodel.pkl")
# Out:
# ['mlmodel.pkl']

# %%
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']
